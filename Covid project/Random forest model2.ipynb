# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os

# %%
os.chdir(r"C:\Users\vbaburao\Documents") 
os.getcwd()
# Out:
# 'C:\\Users\\vbaburao\\Documents'

# %%
dataframe= pd.read_csv('decision tree.csv')

# %%
dfr =dataframe.drop('Date',axis=1)

# %%
dfr
# Out:
#     Covid cases  City traific   sales data
# 0           2.0          1.12  59168881.42
# 1           2.0          1.16  61797572.85
# 2           4.0          1.13  61957686.01
# 3           8.0          1.18  60915291.16
# 4          14.0          1.17  61825051.68
# 5          19.0          1.20  56422640.19
# 6          25.0          1.05  43282534.88
# 7          30.0          1.12  62983372.61
# 8          34.0          1.17  62430068.60
# 9          52.0          1.14  63449606.41
# 10         76.0          1.07  71641835.69
# 11         98.0          0.96  74311890.98
# 12        121.0          0.88  68581539.05
# 13        200.0          0.73  53873179.08
# 14        234.0          0.62  84027209.64
# 15        291.0          0.45  86355574.79
# 16        428.0          0.33  90880066.29
# 17        621.0          0.25  87035136.44
# 18        964.0          0.19  77936544.25
# 19       1178.0          0.17  66962942.29
# 20       1546.0          0.17  42152267.25
# 21       1891.0          0.13  58541127.35
# 22       2201.0          0.11  47879241.95
# 23       2433.0          0.12  45315852.36
# 24       2915.0          0.11  44173625.09
# 25       3417.0          0.12  47972349.62
# 26       3904.0          0.13  44378948.46
# 27       4256.0          0.13  31298923.25
# 28       4579.0          0.14  49654608.41
# 29       5717.0          0.14  53539130.51
# 30       6836.0          0.12  51290200.03
# 31       7910.0          0.12  50194728.74
# 32       9056.0          0.11  51317135.86
# 33      10278.0          0.13  45259624.84
# 34      11130.0          0.13  32129703.62
# 35      12506.0          0.12  51120384.21
# 36      13717.0          0.12  53885623.84
# 37      15927.0          0.12  52940643.28
# 38      17857.0          0.12  53595624.78
# 39      19638.0          0.08  32702491.69
# 40      20727.0          0.12  44636431.62
# 41      22169.0          0.12  27903043.58
# 42      23430.0          0.11  50571790.68
# 43      25262.0          0.11  51254159.25
# 44      28320.0          0.11  52513455.59

# %%
dfr_norm.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b7c4565261fc> in <module>
# ----> 1 dfr_norm.describe()
#
# NameError: name 'dfr_norm' is not defined

# %%
X = dfr.drop('sales data', axis=1)
Y = dfr['sales data']

# %%
X=X[["Covid cases","City traific"]]
a=X.min()
b=X.max()
X= (X - a) / (b - a)
X
# Out:
#     Covid cases  City traific
# 0      0.000000      0.928571
# 1      0.000000      0.964286
# 2      0.000071      0.937500
# 3      0.000212      0.982143
# 4      0.000424      0.973214
# 5      0.000600      1.000000
# 6      0.000812      0.866071
# 7      0.000989      0.928571
# 8      0.001130      0.973214
# 9      0.001766      0.946429
# 10     0.002613      0.883929
# 11     0.003390      0.785714
# 12     0.004202      0.714286
# 13     0.006992      0.580357
# 14     0.008193      0.482143
# 15     0.010206      0.330357
# 16     0.015043      0.223214
# 17     0.021859      0.151786
# 18     0.033971      0.098214
# 19     0.041528      0.080357
# 20     0.054524      0.080357
# 21     0.066707      0.044643
# 22     0.077654      0.026786
# 23     0.085846      0.035714
# 24     0.102867      0.026786
# 25     0.120595      0.035714
# 26     0.137792      0.044643
# 27     0.150222      0.044643
# 28     0.161629      0.053571
# 29     0.201815      0.053571
# 30     0.241331      0.035714
# 31     0.279257      0.035714
# 32     0.319726      0.026786
# 33     0.362879      0.044643
# 34     0.392966      0.044643
# 35     0.441557      0.035714
# 36     0.484321      0.035714
# 37     0.562363      0.035714
# 38     0.630518      0.035714
# 39     0.693411      0.000000
# 40     0.731867      0.035714
# 41     0.782788      0.035714
# 42     0.827318      0.026786
# 43     0.892012      0.026786
# 44     1.000000      0.026786

# %%
Y = dfr['sales data']
c=Y.min()
d=Y.max()
Y= (Y - c) / (d - c)
Y
# Out:
# 0     0.496464
# 1     0.538205
# 2     0.540747
# 3     0.524195
# 4     0.538641
# 5     0.452857
# 6     0.244208
# 7     0.557034
# 8     0.548248
# 9     0.564437
# 10    0.694520
# 11    0.736917
# 12    0.645926
# 13    0.412375
# 14    0.891185
# 15    0.928156
# 16    1.000000
# 17    0.938947
# 18    0.794472
# 19    0.620225
# 20    0.226261
# 21    0.486496
# 22    0.317198
# 23    0.276495
# 24    0.258357
# 25    0.318677
# 26    0.261618
# 27    0.053923
# 28    0.345389
# 29    0.407070
# 30    0.371360
# 31    0.353965
# 32    0.371788
# 33    0.275602
# 34    0.067114
# 35    0.368664
# 36    0.412572
# 37    0.397567
# 38    0.407968
# 39    0.076210
# 40    0.265706
# 41    0.000000
# 42    0.359953
# 43    0.370788
# 44    0.390784
# Name: sales data, dtype: float64

# %%
from sklearn.model_selection import TimeSeriesSplit
from matplotlib import pyplot
X=X.values
splits = TimeSeriesSplit(n_splits=4)
pyplot.figure(1)
index = 1
for train_index, test_index in splits.split(X):
	X_train = X[train_index]
	X_test = X[test_index]
	print('Observations: %d' % (len(X_train) + len(X_test)))
	print('Training Observations: %d' % (len(X_train)))
	print('Testing Observations: %d' % (len(X_test)))
# Out:
# Observations: 18
# Training Observations: 9
# Testing Observations: 9
# Observations: 27
# Training Observations: 18
# Testing Observations: 9
# Observations: 36
# Training Observations: 27
# Testing Observations: 9
# Observations: 45
# Training Observations: 36
# Testing Observations: 9

# %%
from sklearn.model_selection import TimeSeriesSplit
from matplotlib import pyplot
Y = Y
splits = TimeSeriesSplit(n_splits=4)
pyplot.figure(1)
index = 1
for train_index, test_index in splits.split(Y):
	Y_train = Y[train_index]
	Y_test = Y[test_index]
	print('Observations: %d' % (len(Y_train) + len(Y_test)))
	print('Training Observations: %d' % (len(Y_train)))
	print('Testing Observations: %d' % (len(Y_test)))
# Out:
# Observations: 18
# Training Observations: 9
# Testing Observations: 9
# Observations: 27
# Training Observations: 18
# Testing Observations: 9
# Observations: 36
# Training Observations: 27
# Testing Observations: 9
# Observations: 45
# Training Observations: 36
# Testing Observations: 9

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=200, oob_score=True, random_state=0)
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=None, oob_score=True,
#                       random_state=0, verbose=0, warm_start=False)

# %%
y_pred1 = rf.predict(X_test)

# %%
dataset=pd.DataFrame({'Actual':Y_test, 'Predicted':y_pred1})
dataset
# Out:
#       Actual  Predicted
# 36  0.412572    0.29139
# 37  0.397567    0.29139
# 38  0.407968    0.29139
# 39  0.076210    0.29088
# 40  0.265706    0.29139
# 41  0.000000    0.29139
# 42  0.359953    0.29088
# 43  0.370788    0.29088
# 44  0.390784    0.29088

# %%
Y_test_denor=(Y_test)*(d-c)+c
y_pred1_denor=(y_pred1)*(d-c)+c
dataset_denor=pd.DataFrame({'Actual':Y_test_denor, 'Predicted':y_pred1_denor})
dataset_denor
# Out:
#          Actual     Predicted
# 36  53885623.84  4.625392e+07
# 37  52940643.28  4.625392e+07
# 38  53595624.78  4.625392e+07
# 39  32702491.69  4.622178e+07
# 40  44636431.62  4.625392e+07
# 41  27903043.58  4.625392e+07
# 42  50571790.68  4.622178e+07
# 43  51254159.25  4.622178e+07
# 44  52513455.59  4.622178e+07

# %%
# Evaluating the Algorithm
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, y_pred1))  
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, y_pred1))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Y_test, y_pred1)))
# Out:
# Mean Absolute Error: 0.12495182228313001
# Mean Squared Error: 0.021370824673754084
# Root Mean Squared Error: 0.1461876351602764

# %%
test = pd.read_csv('predict.csv')

# %%
test_norm=(test - test.min()) / (test.max() - test.min())

# %%
test_norm
# Out:
#     Covid cases  City traific
# 0      0.000000           1.0
# 1      0.039679           0.8
# 2      0.080413           0.6
# 3      0.117097           0.6
# 4      0.157105           1.0
# 5      0.204840           0.8
# 6      0.265227           0.6
# 7      0.333148           0.4
# 8      0.407548           0.4
# 9      0.470635           0.2
# 10     0.524974           0.2
# 11     0.584532           0.4
# 12     0.643648           0.4
# 13     0.713464           0.2
# 14     0.781078           0.2
# 15     0.848863           0.2
# 16     0.908058           0.0
# 17     0.954012           0.2
# 18     1.000000           0.4

# %%
y_pred = rf.predict(test_norm)

# %%
y_pred
y_pred_denor=(y_pred)*(d-c)+c
y_pred_denor
# Out:
# array([58407389.42300501, 71218916.82939994, 50375917.69680002,
#        49113642.19360003, 49640165.68874998, 53014368.95141251,
#        52644914.72981001, 53392003.67801002, 47021252.18855002,
#        48699142.39595002, 48699142.39595002, 48635460.03870001,
#        48635460.03870001, 48699142.39595002, 48699142.39595002,
#        48699142.39595002, 46221780.96557498, 48699142.39595002,
#        48635460.03870001])

# %%
y_final=pd.DataFrame(y_pred_denor)

# %%
y_final
# Out:
#                0
# 0   5.840739e+07
# 1   7.121892e+07
# 2   5.037592e+07
# 3   4.911364e+07
# 4   4.964017e+07
# 5   5.301437e+07
# 6   5.264491e+07
# 7   5.339200e+07
# 8   4.702125e+07
# 9   4.869914e+07
# 10  4.869914e+07
# 11  4.863546e+07
# 12  4.863546e+07
# 13  4.869914e+07
# 14  4.869914e+07
# 15  4.869914e+07
# 16  4.622178e+07
# 17  4.869914e+07
# 18  4.863546e+07

# %%
y_final.to_excel('y_final.xlsx', index = False)

# %%
pred_df = pd.concat([test_norm, y_final], axis=1)

# %%
pred_df
# Out:
#     Covid cases  City traific             0
# 0      0.000000           1.0  5.840739e+07
# 1      0.039679           0.8  7.121892e+07
# 2      0.080413           0.6  5.037592e+07
# 3      0.117097           0.6  4.911364e+07
# 4      0.157105           1.0  4.964017e+07
# 5      0.204840           0.8  5.301437e+07
# 6      0.265227           0.6  5.264491e+07
# 7      0.333148           0.4  5.339200e+07
# 8      0.407548           0.4  4.702125e+07
# 9      0.470635           0.2  4.869914e+07
# 10     0.524974           0.2  4.869914e+07
# 11     0.584532           0.4  4.863546e+07
# 12     0.643648           0.4  4.863546e+07
# 13     0.713464           0.2  4.869914e+07
# 14     0.781078           0.2  4.869914e+07
# 15     0.848863           0.2  4.869914e+07
# 16     0.908058           0.0  4.622178e+07
# 17     0.954012           0.2  4.869914e+07
# 18     1.000000           0.4  4.863546e+07

# %%
rf.score(X_train,Y_train)
# Out:
# 0.9375210962968294
